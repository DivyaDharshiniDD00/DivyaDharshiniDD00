# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
df= df.reindex(['a','b','c','d','e','f','g','h'])
print(df)
# Out:
#         one       two     three
# a -1.261458 -0.061651  0.465892
# b       NaN       NaN       NaN
# c -0.540263 -1.031800 -1.102845
# d       NaN       NaN       NaN
# e  0.473060  0.100896  0.686428
# f -0.384740  0.004725  1.185081
# g       NaN       NaN       NaN
# h  0.355637 -0.614603  0.532807

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
df= df.reindex(['a','b','c','d','e','f','g','h'])
print(df['one'].isnull())
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
df= df.reindex(['a','b','c','d','e','f','g','h'])
print(df['one'].notnull())
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# f     True
# g    False
# h     True
# Name: one, dtype: bool

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
df= df.reindex(['a','b','c','d','e','f','g','h'])
print(df['one'].sum())
# Out:
# -1.1578662655299445

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.randn(3,3),index=['a','c','e'],columns=['one','two','three'])
df= df.reindex(['a','b','c'])
print(df)
print("NaN replaced with '0':")
print(df.fillna(0))
# Out:
#         one       two     three
# a -0.248157 -1.593830  0.292857
# b       NaN       NaN       NaN
# c -0.005635  0.131259 -0.687251
# NaN replaced with '0':
#         one       two     three
# a -0.248157 -1.593830  0.292857
# b  0.000000  0.000000  0.000000
# c -0.005635  0.131259 -0.687251

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
df= df.reindex(['a','b','c','d','e','f','g','h'])
print(df.dropna())
# Out:
#         one       two     three
# a  1.402004 -0.493726  1.357703
# c  3.043400  2.030504  0.048161
# e -0.424646  0.332530  1.507968
# f  0.971488  0.942170  0.004697
# h -0.943748 -1.149739  0.296621

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
print(df)
# Out:
#         one       two     three
# a  1.125811  0.629326 -0.705143
# c  0.302184  0.345489  0.754969
# e  0.403230  0.257039 -0.547654
# f  1.600931 -0.756963  0.410658
# h -0.274530 -0.569622 -0.441686

# %%
import pandas as pd
one= pd.DataFrame({'Name':['divya','deenu','siddhu','mathi'],'subject':['sci','ss','mat','eng'],'marks scored':[99,98,97,96]},index=[1,2,3,4])
two= pd.DataFrame({'Name':['abarna','deepak','vishalni','keerthika'],'subject':['sci','ss','mat','eng'],'marks scored':[95,94,93,92]},index=[1,2,3,4])
print(pd.concat([one,two]))
# Out:
#         Name subject  marks scored
# 1      divya     sci            99
# 2      deenu      ss            98
# 3     siddhu     mat            97
# 4      mathi     eng            96
# 1     abarna     sci            95
# 2     deepak      ss            94
# 3   vishalni     mat            93
# 4  keerthika     eng            92

# %%
import pandas as pd
one= pd.DataFrame({'Name':['divya','deenu','siddhu','mathi'],'subject':['sci','ss','mat','eng'],'marks scored':[99,98,97,96]},index=[1,2,3,4])
two= pd.DataFrame({'Name':['abarna','deepak','vishalni','keerthika'],'subject':['sci','ss','mat','eng'],'marks scored':[95,94,93,92]},index=[1,2,3,4])
print(pd.concat([one,two],keys=['x','y']))
# Out:
#           Name subject  marks scored
# x 1      divya     sci            99
#   2      deenu      ss            98
#   3     siddhu     mat            97
#   4      mathi     eng            96
# y 1     abarna     sci            95
#   2     deepak      ss            94
#   3   vishalni     mat            93
#   4  keerthika     eng            92

# %%
import pandas as pd
one= pd.DataFrame({'Name':['divya','deenu','siddhu','mathi'],'subject':['sci','ss','mat','eng'],'marks scored':[99,98,97,96]},index=[1,2,3,4])
two= pd.DataFrame({'Name':['abarna','deepak','vishalni','keerthika'],'subject':['sci','ss','mat','eng'],'marks scored':[95,94,93,92]},index=[1,2,3,4])
print(pd.concat([one,two],keys=['x','y'],ignore_index=True))
# Out:
#         Name subject  marks scored
# 0      divya     sci            99
# 1      deenu      ss            98
# 2     siddhu     mat            97
# 3      mathi     eng            96
# 4     abarna     sci            95
# 5     deepak      ss            94
# 6   vishalni     mat            93
# 7  keerthika     eng            92

# %%
import pandas as pd
one= pd.DataFrame({'Name':['divya','deenu','siddhu','mathi'],'subject':['sci','ss','mat','eng'],'marks scored':[99,98,97,96]},index=[1,2,3,4])
two= pd.DataFrame({'Name':['abarna','deepak','vishalni','keerthika'],'subject':['sci','ss','mat','eng'],'marks scored':[95,94,93,92]},index=[1,2,3,4])
print(pd.concat([one,two],axis=1))
# Out:
#      Name subject  marks scored       Name subject  marks scored
# 1   divya     sci            99     abarna     sci            95
# 2   deenu      ss            98     deepak      ss            94
# 3  siddhu     mat            97   vishalni     mat            93
# 4   mathi     eng            96  keerthika     eng            92

# %%
import pandas as pd
one= pd.DataFrame({'Name':['divya','deenu','siddhu','mathi'],'subject':['sci','ss','mat','eng'],'marks scored':[99,98,97,96]},index=[1,2,3,4])
two= pd.DataFrame({'Name':['abarna','deepak','vishalni','keerthika'],'subject':['sci','ss','mat','eng'],'marks scored':[95,94,93,92]},index=[1,2,3,4])
print(pd.concat([one,two],axis=0))
# Out:
#         Name subject  marks scored
# 1      divya     sci            99
# 2      deenu      ss            98
# 3     siddhu     mat            97
# 4      mathi     eng            96
# 1     abarna     sci            95
# 2     deepak      ss            94
# 3   vishalni     mat            93
# 4  keerthika     eng            92

# %%
import pandas as pd
one= pd.DataFrame({'Name':['divya','deenu','siddhu','mathi'],'subject':['sci','ss','mat','eng'],'marks scored':[99,98,97,96]},index=[1,2,3,4])
two= pd.DataFrame({'Name':['abarna','deepak','vishalni','keerthika'],'subject':['sci','ss','mat','eng'],'marks scored':[95,94,93,92]},index=[1,2,3,4])
print(one.append(two))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11620\1589859723.py in ?()
#       1 import pandas as pd
#       2 one= pd.DataFrame({'Name':['divya','deenu','siddhu','mathi'],'subject':['sci','ss','mat','eng'],'marks scored':[99,98,97,96]},index=[1,2,3,4])
#       3 two= pd.DataFrame({'Name':['abarna','deepak','vishalni','keerthika'],'subject':['sci','ss','mat','eng'],'marks scored':[95,94,93,92]},index=[1,2,3,4])
# ----> 4 print(one.append(two))
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
import pandas as pd
print (pd.datetime.now())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 import pandas as pd
# ----> 2 print (pd.datetime.now())
#
# AttributeError: module 'pandas' has no attribute 'datetime'

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
   # !pip install pandas

# %%
import pandas as pd
print(pd.datetime.now())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 import pandas as pd
# ----> 2 print(pd.datetime.now())
#
# AttributeError: module 'pandas' has no attribute 'datetime'

# %%
import pandas as pd
print(pd.date_range('16/2/2024',periods=5))
# Out:
# DatetimeIndex(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#                '2024-02-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
print(pd.date_range('16/2/2024',periods=5,freq='M'))
# Out:
# DatetimeIndex(['2024-02-29', '2024-03-31', '2024-04-30', '2024-05-31',
#                '2024-06-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
imDort pandas as pd
print(pd.date_range('16/2/2024',periods=5,freq='Days'))
# Out:
#   Cell In[34], line 1
#     imDort pandas as pd
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
start= pd.datetime(2012,2,2)
end= pd.datetime(2013,2,2)
print(pd.date_range(start,end))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 import pandas as pd
# ----> 2 start= pd.datetime(2012,2,2)
#       3 end= pd.datetime(2013,2,2)
#       4 print(pd.date_range(start,end))
#
# AttributeError: module 'pandas' has no attribute 'datetime'

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.randn(10,4),index=pd.date_range('16/2/2024',periods=10),columns=list('ABCD'))
df.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.randn(10,4),index=pd.date_range('16/2/2024',periods=10),columns=list('ABCD'))
df.plot.bar()
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.rand(10,6),columns=['divya','deenu','siddhu','mathi','abarna','deepak'])
df.plot.bar()
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.rand(10,6),columns=['divya','deenu','siddhu','mathi','abarna','deepak'])
df.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.rand(10,6),columns=['divya','deenu','siddhu','mathi','abarna','deepak'])
df.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.rand(10,6),columns=['divya','deenu','siddhu','mathi','abarna','deepak'])
df.plot.bar(stacked=False)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.rand(10,6),columns=['divya','deenu','siddhu','mathi','abarna','deepak'])
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
