# %%
! pip install pandas

# %%
#pandas 
#high performance dataanalysis tool
#working with large dataset 
#supports or load files with different formats
#more felxible
#it represents in tabular form(rows and column)
#working on missing data
#indexing, slicing,subsetting the large data
#merge and join two different datasets easily
#we can also reshape the datasets

# %%
#data structures
#series-(one dimensional)-eg:list
#dataframes-(two dimensional)-eg:list/dictionary/series/another dataframe

# %%
#syntax for series
#pd.series(data,index)
#syntax for dataframes
#most effective to analysis on the dataset
#pd.dataframe(data)

# %%
import pandas as pd
lst=[10,20,30,40,50]
pd.Series(lst)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series(lst, index=['i','ii','iii','iv','v'])
# Out:
# i      10
# ii     20
# iii    30
# iv     40
# v      50
# dtype: int64

# %%
dic={"name":['raja','jass','kuttu'],"percentage":[50,90,80]}
pd.DataFrame(dic)
# Out:
#     name  percentage
# 0   raja          50
# 1   jass          90
# 2  kuttu          80

# %%
#creating series
#empty series
#series using array
#series using tuples
#series using dictionary

# %%
import pandas as pd

# %%
#empty series
fs=pd.Series()

# %%
fs
# Out:
# Series([], dtype: object)

# %%
1
# Out:
# 1

# %%
#series in list
lst1=[10,20,30,40,50]
fs=pd.Series(lst1)
print(fs)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
fs=pd.Series(lst1,index=['a','b','c','d','e'])
print(fs)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
import numpy as np
a= np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(a)
# Out:
# [1 2 3 4 5]

# %%
fs1=pd.Series(a)

# %%
print(fs1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
d={"a":10,"b":20,"c":30,"d":40}
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
tu=[('a',10),('b',20),('c',30)]
pd.Series(tu)
# Out:
# 0    (a, 10)
# 1    (b, 20)
# 2    (c, 30)
# dtype: object

# %%
#creating dataframes in pandas
load the data from excel file
load the data from csv file 
create Df using disctinory
create Df using list of tuples

syntax
import pandas as pd
df=pd.read_excel("path")

df=pd.read_csv("path")
# Out:
#   Cell In[41], line 2
#     load the data from excel file
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
data=pd.read_csv("C:/Users/Goutham R/Downloads/Lung_Cancer_Dataset.csv")
print(data)
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
pd.DataFrame(data)
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
data.head(10)
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
# 5      F   75        1               2        1              1
# 6      M   52        2               1        1              1
# 7      F   51        2               2        2              2
# 8      F   68        2               1        2              1
# 9      M   53        2               2        2              2
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# ...

# %%
data.tail()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 304         2                    2                      2           1
# ...

# %%
data.tail(10)
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 299      M   65        2               2        2              2
# 300      F   63        2               2        2              2
# 301      M   64        1               2        2              2
# 302      F   65        2               2        2              2
# 303      M   51        1               2        1              1
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 299                1         2         2         1                  1
# 300                2         2         2         2                  1
# ...

# %%
data.isnull()
# Out:
#      GENDER    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0     False  False    False           False    False          False
# 1     False  False    False           False    False          False
# 2     False  False    False           False    False          False
# 3     False  False    False           False    False          False
# 4     False  False    False           False    False          False
# ..      ...    ...      ...             ...      ...            ...
# 304   False  False    False           False    False          False
# 305   False  False    False           False    False          False
# 306   False  False    False           False    False          False
# 307   False  False    False           False    False          False
# 308   False  False    False           False    False          False
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0              False     False     False     False              False
# ...

# %%
#create a dataframe from dict of series

import pandas as pd
d = {'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])}

df=pd.DataFrame(d)
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
# e  NaN    5

# %%
import pandas as pd

d={'one':pd.Series([1,2,3],index=['a','b','c']),
    'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print(df['two'])
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: two, dtype: int64

# %%
#column addition
d={'one':pd.Series([1,2,3],index=['a','b','c']),
    'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}

df=pd.DataFrame(d)

#adding new column
print('addiding new column using the passing Series:')
 
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)

print("adding a new column using existing columns:")
df['four']=df['one']+df['three']

print(df)
# Out:
# addiding new column using the passing Series:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# adding a new column using existing columns:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %%
d={'one':pd.Series([1,2,3],index=['a','b','c']),
    'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}

df=pd.DataFrame(d)

print("our df is:")
print(df)

#using del function
print ("deleting the first cloumn using del func:")
del df ['one']
print(df)

#using pop function
       
print ("deleting the first cloumn using pop func:")
df.pop ('two')
print(df)
# Out:
# our df is:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
# deleting the first cloumn using del func:
#    two
# a    1
# b    2
# c    3
# d    4
# deleting the first cloumn using pop func:
# Empty DataFrame
# Columns: []
# Index: [a, b, c, d]

# %%
#row selection 

d={'one':pd.Series([1,2,3],index=['a','b','c']),
    'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}

df=pd.DataFrame(d)

print (df.loc['b'])
# Out:
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %%
df=pd.DataFrame(d)
print(df.iloc[3])
# Out:
# one    NaN
# two    4.0
# Name: d, dtype: float64

# %%
#slicing row

d={'one':pd.Series([1,2,3,4],index=['a','b','c','d']),
    'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}

df=pd.DataFrame(d)

print(df[2:4])
# Out:
#    one  two
# c    3    3
# d    4    4

# %%
#add new rows to a DataFrame using the append function.
import pandas as pd

df= pd.DataFrame([[1,2],[3,4]],columns=['a','b'])
df2= pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
print(df)
print(df2)

x=df.concat(df2)
print(x)
# Out:
#    a  b
# 0  1  2
# 1  3  4
#    a  b
# 0  5  6
# 1  7  8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_45452\663457358.py in ?()
#       5 df2= pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
#       6 print(df)
#       7 print(df2)
#       8
# ----> 9 x=df.concat(df2)
#      10 print(x)
#
# ~\anaconda3\New folder\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
#deletion of rows

import pandas as pd

df= pd.DataFrame([[1,2],[3,4]],columns=['a','b'])
df2= pd.DataFrame([[5,6],[7,8]],columns=['a','b'])


df=df.drop(0)
print(df)
# Out:
#    a  b
# 1  3  4

# %%
#basic functionality
#transpose
#axes
#dtypes
#ndim
#shape
#size
#value
#head
#tail

# %%
import pandas as pd
import numpy as np

#create a dictionary of series
d={'name':pd.Series(['tom','james','ricky','vin','steve','smith','jack']),
  'age':pd.Series([25,26,25,23,30,29,23]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}
#create a DataFrame
df= pd.DataFrame(d)
print("our data series is:")
print(df)
# Out:
# our data series is:
#     name  age  rating
# 0    tom   25    4.23
# 1  james   26    3.24
# 2  ricky   25    3.98
# 3    vin   23    2.56
# 4  steve   30    3.20
# 5  smith   29    4.63
# 6   jack   23    3.80

# %%
#transport(T)
import pandas as pd
import numpy as np

#create a dictionary of series
d={'name':pd.Series(['tom','james','ricky','vin','steve','smith','jack']),
  'age':pd.Series([25,26,25,23,30,29,23]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}
#create a DataFrame
df= pd.DataFrame(d)
print("the transpose of our data series is:")
print(df.T)
# Out:
# the transpose of our data series is:
#            0      1      2     3      4      5     6
# name     tom  james  ricky   vin  steve  smith  jack
# age       25     26     25    23     30     29    23
# rating  4.23   3.24   3.98  2.56    3.2   4.63   3.8

# %%
#axis
import pandas as pd
import numpy as np

#create a Dictionary of series
d={'name':pd.Series(['tom','james','ricky','vin','steve','smith','jack']),
  'age':pd.Series([25,26,25,23,30,29,23,35]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}
#create a DataFrame
df= pd.DataFrame(d)
print("Row axis lables and column axis lables:")
print(df.axes)
# Out:
# Row axis lables and column axis lables:
# [RangeIndex(start=0, stop=8, step=1), Index(['name', 'age', 'rating'], dtype='object')]

# %%
#dtypes
import pandas as pd
import numpy as np

#create a Dictionary of series
d={'Name':pd.Series(['tom','james','ricky','vin','steve','smith','jack']),
  'Age':pd.Series([25,26,25,23,30,29,23,35]),
  'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}
#create a DataFrame
df= pd.DataFrame(d)
print("The datatypes of each column are:")
print(df.dtypes)
# Out:
# The datatypes of each column are:
# Name       object
# Age         int64
# Rating    float64
# dtype: object

# %% [markdown]
# #empty
#
# import pandas as pd
# import numpy as np
#
# #create a Dictionary of series
# d={'name':pd.Series(['tom','james','ricky','vin','steve','smith','jack']),
#   'age':pd.Series([25,26,25,23,30,29,23,35]),
#   'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}
# #create a DataFrame
# df= pd.DataFrame(d)
# print("is the object empty?")
# print(df.empty)

# %%
#empty

import pandas as pd
import numpy as np

#create a Dictionary of series
d={'name':pd.Series(['tom','james','ricky','vin','steve','smith','jack']),
  'age':pd.Series([25,26,25,23,30,29,23,35]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}
#create a DataFrame
df= pd.DataFrame(d)
print("is the object empty?")
print(df.empty)
# Out:
# is the object empty?
# False

# %%
#ndim

import pandas as pd
import numpy as np

#create a Dictionary of series
d={'name':pd.Series(['tom','james','ricky','vin','steve','smith','jack']),
  'age':pd.Series([25,26,25,23,30,29,23,35]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}
#create a DataFrame
df= pd.DataFrame(d)
print("the object is?")
print(df)
print("the dimension of the object is:")
print(df.ndim)
# Out:
# the object is?
#     name  age  rating
# 0    tom   25    4.23
# 1  james   26    3.24
# 2  ricky   25    3.98
# 3    vin   23    2.56
# 4  steve   30    3.20
# 5  smith   29    4.63
# 6   jack   23    3.80
# 7    NaN   35     NaN
# the dimension of the object is:
# 2

# %%
#shape

import pandas as pd
import numpy as np

#create a Dictionary of series
d={'name':pd.Series(['tom','james','ricky','vin','steve','smith','jack']),
  'age':pd.Series([25,26,25,23,30,29,23,35]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}
#create a DataFrame
df= pd.DataFrame(d)
print("our object is:")
print(df)
print("the shape of the object is:")
print(df.shape)
print("size of the object is?")
print(df.size)
print("values of the data frame:")
print(df.values)
# Out:
# our object is:
#     name  age  rating
# 0    tom   25    4.23
# 1  james   26    3.24
# 2  ricky   25    3.98
# 3    vin   23    2.56
# 4  steve   30    3.20
# 5  smith   29    4.63
# 6   jack   23    3.80
# 7    NaN   35     NaN
# the shape of the object is:
# (8, 3)
# size of the object is?
# 24
# values of the data frame:
# [['tom' 25 4.23]
#  ['james' 26 3.24]
#  ['ricky' 25 3.98]
#  ['vin' 23 2.56]
#  ['steve' 30 3.2]
#  ['smith' 29 4.63]
#  ['jack' 23 3.8]
#  [nan 35 nan]]

# %%
import pandas as pd
a=pd.Series([10,20,30,40,50])
b=pd.Series([1,2,3,4,5])
print(a)
print(b)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#mathematical functions in pandas series
a+b
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
a.add(b)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
a-b
# Out:
# 0     9
# 1    18
# 2    27
# 3    36
# 4    45
# dtype: int64

# %%
a.subtract(b)
# Out:
# 0     9
# 1    18
# 2    27
# 3    36
# 4    45
# dtype: int64

# %%
a*b
# Out:
# 0     10
# 1     40
# 2     90
# 3    160
# 4    250
# dtype: int64

# %%
a.multiply(b)
# Out:
# 0     10
# 1     40
# 2     90
# 3    160
# 4    250
# dtype: int64

# %%
a/b
# Out:
# 0    10.0
# 1    10.0
# 2    10.0
# 3    10.0
# 4    10.0
# dtype: float64

# %%
a.divide(b)
# Out:
# 0    10.0
# 1    10.0
# 2    10.0
# 3    10.0
# 4    10.0
# dtype: float64

# %%
a%b
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
a<b
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
a>b
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
c=pd.Series([10,1,4,7,2])
b>c
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
b<c
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
b==c
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
a**b
# Out:
# 0           10
# 1          400
# 2        27000
# 3      2560000
# 4    312500000
# dtype: int64

# %%
a.pow(b)
# Out:
# 0           10
# 1          400
# 2        27000
# 3      2560000
# 4    312500000
# dtype: int64

# %%
#descriptive analysis
import pandas as pd
import numpy as np

#create a dictionary of series

d={'name':pd.Series(['tom','james','ricky','vin','steve','smith','jack']),
  'age':pd.Series([25,26,25,23,30,29,23,35]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}

#create a DataFrame  
df= pd.DataFrame(d)
print(df)
# Out:
#     name  age  rating
# 0    tom   25    4.23
# 1  james   26    3.24
# 2  ricky   25    3.98
# 3    vin   23    2.56
# 4  steve   30    3.20
# 5  smith   29    4.63
# 6   jack   23    3.80
# 7    NaN   35     NaN

# %%
import pandas as pd
import numpy as np

#create a dictionary of series

d={
  'age':pd.Series([25,26,25,23,30,29,23,35]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}

#create a DataFrame
df= pd.DataFrame(d)
print(df.sum())
# Out:
# age       216.00
# rating     25.64
# dtype: float64

# %%
#axis=1
import pandas as pd
import numpy as np

#create a dictionary of series

d={
  'age':pd.Series([25,26,25,23,30,29,23,35]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}

#create a DataFrame
df= pd.DataFrame(d)
print(df.sum(1))
# Out:
# 0    29.23
# 1    29.24
# 2    28.98
# 3    25.56
# 4    33.20
# 5    33.63
# 6    26.80
# 7    35.00
# dtype: float64

# %%
#mean
import pandas as pd
import numpy as np

#create a dictionary of series

d={
  'age':pd.Series([25,26,25,23,30,29,23,35]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}

#create a DataFrame
df= pd.DataFrame(d)
print(df.mean())
# Out:
# age       27.000000
# rating     3.662857
# dtype: float64

# %%
#std()
import pandas as pd
import numpy as np

#create a dictionary of series

d={
  'age':pd.Series([25,26,25,23,30,29,23,35]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8])}

#create a DataFrame
df= pd.DataFrame(d)
print(df.std())
# Out:
# age       4.105745
# rating    0.705425
# dtype: float64

# %%
#summarizing data
using describe() which computes the summary of statics in dataframe

#include-argument
object=summarize string columns
number=summarize numeric columns
all=summarize all columns together

# %%
import pandas as pd
import numpy as np

#create a dictionary of series
d={'name':pd.Series(['hari','indhu','vaishu','vishnu','magi','jass','manu','brindha','harsha','pavi','sarika','ramya']),
  'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8,3.78,2.98,4.80,4.10,3.65])}

#create a DataFrame
df= pd.DataFrame(d)
print(df.describe())
# Out:
#              Age     rating
# count  12.000000  12.000000
# mean   31.833333   3.745833
# std     9.232682   0.665206
# min    23.000000   2.560000
# 25%    25.000000   3.230000
# 50%    29.500000   3.790000
# 75%    35.500000   4.132500
# max    51.000000   4.800000

# %%
import pandas as pd
import numpy as np

#create a dictionary of series
d={'name':pd.Series(['hari','indhu','vaishu','vishnu','magi','jass','manu','brindha','harsha','pavi','sarika','ramya']),
  'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8,3.78,2.98,4.80,4.10,3.65])}

#create a DataFrame
df= pd.DataFrame(d)
print(df.describe(include=['object']))
# Out:
#         name
# count     12
# unique    12
# top     hari
# freq       1

# %%
import pandas as pd
import numpy as np

#create a dictionary of series
d={'name':pd.Series(['hari','indhu','vaishu','vishnu','magi','jass','manu','brindha','harsha','pavi','sarika','ramya']),
  'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8,3.78,2.98,4.80,4.10,3.65])}

#create a DataFrame
df= pd.DataFrame(d)
print(df.describe(include='all'))
# Out:
#         name        Age     rating
# count     12  12.000000  12.000000
# unique    12        NaN        NaN
# top     hari        NaN        NaN
# freq       1        NaN        NaN
# mean     NaN  31.833333   3.745833
# std      NaN   9.232682   0.665206
# min      NaN  23.000000   2.560000
# 25%      NaN  25.000000   3.230000
# 50%      NaN  29.500000   3.790000
# 75%      NaN  35.500000   4.132500
# max      NaN  51.000000   4.800000

# %%
import pandas as pd
import numpy as np

#create a dictionary of series
d={'name':pd.Series(['hari','indhu','vaishu','vishnu','magi','jass','manu','brindha','harsha','pavi','sarika','ramya']),
  'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8,3.78,2.98,4.80,4.10,3.65])}

#create a DataFrame
df= pd.DataFrame(d)
print(df.describe(include='object'))
# Out:
#         name
# count     12
# unique    12
# top     hari
# freq       1

# %%
import pandas as pd
import numpy as np

#create a dictionary of series
d={'name':pd.Series(['hari','indhu','vaishu','vishnu','magi','jass','manu','brindha','harsha','pavi','sarika','ramya']),
  'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
  'rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.63,3.8,3.78,2.98,4.80,4.10,3.65])}

#create a DataFrame
df= pd.DataFrame(d)
print(df.describe(include='all'))
# Out:
#         name        Age     rating
# count     12  12.000000  12.000000
# unique    12        NaN        NaN
# top     hari        NaN        NaN
# freq       1        NaN        NaN
# mean     NaN  31.833333   3.745833
# std      NaN   9.232682   0.665206
# min      NaN  23.000000   2.560000
# 25%      NaN  25.000000   3.230000
# 50%      NaN  29.500000   3.790000
# 75%      NaN  35.500000   4.132500
# max      NaN  51.000000   4.800000

# %%
import pandas as pd
data=pd.read_csv("C:/Users/Goutham R/Downloads/Lung_Cancer_Dataset.csv")
print(data)
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data.head(10)
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
# 5      F   75        1               2        1              1
# 6      M   52        2               1        1              1
# 7      F   51        2               2        2              2
# 8      F   68        2               1        2              1
# 9      M   53        2               2        2              2
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# ...

# %%
data.tail()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 304         2                    2                      2           1
# ...

# %%
data.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# ...

# %%
data.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
data.shape
# Out:
# (309, 16)

# %%
data['AGE'].head()
# Out:
# 0    69
# 1    74
# 2    59
# 3    63
# 4    63
# Name: AGE, dtype: int64

# %%
data[['AGE','SMOKING']]
# Out:
#      AGE  SMOKING
# 0     69        1
# 1     74        2
# 2     59        1
# 3     63        2
# 4     63        1
# ..   ...      ...
# 304   56        1
# 305   70        2
# 306   58        2
# 307   67        2
# 308   62        1
#
# [309 rows x 2 columns]

# %%
data[1:10]
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
# 5      F   75        1               2        1              1
# 6      M   52        2               1        1              1
# 7      F   51        2               2        2              2
# 8      F   68        2               1        2              1
# 9      M   53        2               2        2              2
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# ...

# %%
data[1:35:3]
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 1       M   74        2               1        1              1
# 4       F   63        1               2        1              1
# 7       F   51        2               2        2              2
# 10      F   61        2               2        2              2
# 13      M   58        2               1        1              1
# 16      M   75        2               1        1              1
# 19      F   61        1               1        1              1
# 22      F   21        2               1        1              1
# 25      M   65        1               2        2              1
# 28      F   53        2               2        2              1
# 31      M   62        2               1        2              1
# 34      M   59        1               2        2              1
#
#     CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# ...

# %%
data[['GENDER','AGE','SMOKING']][:135]
# Out:
#     GENDER  AGE  SMOKING
# 0        M   69        1
# 1        M   74        2
# 2        F   59        1
# 3        M   63        2
# 4        F   63        1
# ..     ...  ...      ...
# 130      F   51        2
# 131      F   61        1
# 132      F   61        2
# 133      M   76        2
# 134      M   71        2
#
# [135 rows x 3 columns]

# %%
data.loc[1]
# Out:
# GENDER                     M
# AGE                       74
# SMOKING                    2
# YELLOW_FINGERS             1
# ANXIETY                    1
# PEER_PRESSURE              1
# CHRONIC DISEASE            2
# FATIGUE                    2
# ALLERGY                    2
# WHEEZING                   1
# ALCOHOL CONSUMING          1
# COUGHING                   1
# SHORTNESS OF BREATH        2
# SWALLOWING DIFFICULTY      2
# CHEST PAIN                 2
# LUNG_CANCER              YES
# Name: 1, dtype: object

# %%
data.loc[1:6]
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
# 5      F   75        1               2        1              1
# 6      M   52        2               1        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
# 5                2         2         2         2                  1         2
# ...

# %%
for index,rows in data.iterrows():
    print(index,rows)
# Out:
# 0 GENDER                     M
# AGE                       69
# SMOKING                    1
# YELLOW_FINGERS             2
# ANXIETY                    2
# PEER_PRESSURE              1
# CHRONIC DISEASE            1
# FATIGUE                    2
# ALLERGY                    1
# WHEEZING                   2
# ALCOHOL CONSUMING          2
# COUGHING                   2
# SHORTNESS OF BREATH        2
# SWALLOWING DIFFICULTY      2
# CHEST PAIN                 2
# LUNG_CANCER              YES
# Name: 0, dtype: object
# 1 GENDER                     M
# AGE                       74
# SMOKING                    2
# YELLOW_FINGERS             1
# ANXIETY                    1
# PEER_PRESSURE              1
# CHRONIC DISEASE            2
# FATIGUE                    2
# ALLERGY                    2
# WHEEZING                   1
# ALCOHOL CONSUMING          1
# COUGHING                   1
# SHORTNESS OF BREATH        2
# SWALLOWING DIFFICULTY      2
# CHEST PAIN                 2
# ...

# %%
data.loc[data['SMOKING']==2]
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 1        M   74        2               1        1              1
# 3        M   63        2               2        2              1
# 6        M   52        2               1        1              1
# 7        F   51        2               2        2              2
# 8        F   68        2               1        2              1
# ..     ...  ...      ...             ...      ...            ...
# 300      F   63        2               2        2              2
# 302      F   65        2               2        2              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 1                  2         2         2         1                  1
# ...

# %%
#sorting the values
import pandas as pd
data=pd.read_csv("C:/Users/Goutham R/Downloads/Lung_Cancer_Dataset.csv")
print(data)
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
data.sort_values("SMOKING")
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 164      F   75        1               2        1              2
# 165      M   63        1               2        2              1
# 166      F   61        1               2        1              2
# 167      M   62        1               1        1              1
# ..     ...  ...      ...             ...      ...            ...
# 179      F   72        2               2        2              2
# 180      M   63        2               2        2              2
# 181      F   74        2               2        2              2
# 67       M   66        2               1        1              1
# 154      F   64        2               2        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data.sort_values("SMOKING",ascending=False)
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 154      F   64        2               2        1              2
# 136      F   56        2               2        2              1
# 124      M   70        2               1        1              1
# 126      M   51        2               1        1              1
# 127      M   58        2               2        2              2
# ..     ...  ...      ...             ...      ...            ...
# 152      F   74        1               2        2              2
# 158      F   56        1               1        2              2
# 159      M   68        1               1        2              2
# 160      F   55        1               1        1              2
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 154                2         1         1         1                  1
# ...

# %%
data.dropna()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
#working with missing data

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])

df=df.reindex(['a','b','c','d','e','f','g','h'])

print(df)
# Out:
#         one       two     three
# a -1.367894 -1.205540  0.748990
# b       NaN       NaN       NaN
# c -0.456553  0.070561 -0.085406
# d       NaN       NaN       NaN
# e -0.814790 -1.681980 -1.146857
# f  1.556248 -0.705329 -0.314697
# g       NaN       NaN       NaN
# h  1.085463 -0.406796 -1.387881

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])

df=df.reindex(['a','b','c','d','e','f','g','h'])

print(df['one'].isnull())
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])

df=df.reindex(['a','b','c','d','e','f','g','h'])

print(df['one'].notnull())
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# f     True
# g    False
# h     True
# Name: one, dtype: bool

# %%
#when summing data ,NA will be treated as Zero
#if the data are all NA, then the result will be NA

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])

df=df.reindex(['a','b','c','d','e','f','g','h'])

print(df['one'].sum())
# Out:
# 3.286316291128664

# %%
#filling the missing values
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])

df=df.reindex(['a','b','c','d','e','f','g','h'])

print(df)
print("NAN replaced with '0':")
print(df.fillna(0))
# Out:
#         one       two     three
# a -0.021770 -0.318090  0.514814
# b       NaN       NaN       NaN
# c  0.231840  2.216692  0.478174
# d       NaN       NaN       NaN
# e -1.596396  0.636387 -0.565782
# f -2.211986  1.034177 -0.789559
# g       NaN       NaN       NaN
# h -0.602522  1.621911 -0.777875
# NAN replaced with '0':
#         one       two     three
# a -0.021770 -0.318090  0.514814
# b  0.000000  0.000000  0.000000
# c  0.231840  2.216692  0.478174
# d  0.000000  0.000000  0.000000
# e -1.596396  0.636387 -0.565782
# f -2.211986  1.034177 -0.789559
# g  0.000000  0.000000  0.000000
# h -0.602522  1.621911 -0.777875

# %%
#drop the missing value
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])

df=df.reindex(['a','b','c','d','e','f','g','h'])

print(df.dropna())
# Out:
#         one       two     three
# a  0.700422  0.704011 -0.275913
# c -0.449337  0.679326  0.463457
# e -0.864143 -1.809881  0.617710
# f  0.150412 -0.517773  0.646012
# h -0.705465  0.857861  0.407359

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])

df=df.reindex(['a','b','c','d','e','f','g','h'])

print(df)
# Out:
#         one       two     three
# a  1.477050 -1.325830 -0.321941
# b       NaN       NaN       NaN
# c  1.013814  0.777960 -0.707559
# d       NaN       NaN       NaN
# e -0.831238 -0.973909  1.720094
# f -1.308608  0.254332  0.887809
# g       NaN       NaN       NaN
# h -0.280560 -0.406196  1.041801

# %%
#concatenation
object- This is a sequence or mapping of series,DataFrme, or panel objects.
axis-{0,1,...},default 0.this is the axis to concatenate along.
join-{'inner','outer'}, default 'outer'. how to handle index on other axis(es).outer for union and inner for intresection.
ignor_index - boolean, default False. if True, do not use the index values on the concatenation axis.the resulting axis. the resulting asix will be

# %%
import pandas as pd

one=pd.DataFrame({'Name':['Arun','adhi','ash','pata','ayush'],
                 'Subject_id':['sci','soc','stat','eng','mat'],
                 'Mark_scored':[98,90,87,69,78]},
                index=[1,2,3,4,5])

two=pd.DataFrame({'Name':['brun','akdhi','abash','abapata','hayush'],
                 'Subject_id':['sci','soc','stat','eng','mat'],
                 'Mark_scored':[89,80,79,97,88]},
                index=[1,2,3,4,5])
print(pd.concat([one,two]))
# Out:
#       Name Subject_id  Mark_scored
# 1     Arun        sci           98
# 2     adhi        soc           90
# 3      ash       stat           87
# 4     pata        eng           69
# 5    ayush        mat           78
# 1     brun        sci           89
# 2    akdhi        soc           80
# 3    abash       stat           79
# 4  abapata        eng           97
# 5   hayush        mat           88

# %%
import pandas as pd

one=pd.DataFrame({'Name':['Arun','adhi','ash','pata','ayush'],
                 'Subject_id':['sci','soc','stat','eng','mat'],
                 'Mark_scored':[98,90,87,69,78]},
                index=[1,2,3,4,5])

two=pd.DataFrame({'Name':['brun','akdhi','abash','abapata','hayush'],
                 'Subject_id':['sci','soc','stat','eng','mat'],
                 'Mark_scored':[89,80,79,97,88]},
                index=[1,2,3,4,5])
print(pd.concat([one,two],keys=['x','y']))
# Out:
#         Name Subject_id  Mark_scored
# x 1     Arun        sci           98
#   2     adhi        soc           90
#   3      ash       stat           87
#   4     pata        eng           69
#   5    ayush        mat           78
# y 1     brun        sci           89
#   2    akdhi        soc           80
#   3    abash       stat           79
#   4  abapata        eng           97
#   5   hayush        mat           88

# %%
import pandas as pd

one=pd.DataFrame({'Name':['Arun','adhi','ash','pata','ayush'],
                 'Subject_id':['sci','soc','stat','eng','mat'],
                 'Mark_scored':[98,90,87,69,78]},
                index=[1,2,3,4,5])

two=pd.DataFrame({'Name':['brun','akdhi','abash','abapata','hayush'],
                 'Subject_id':['sci','soc','stat','eng','mat'],
                 'Mark_scored':[89,80,79,97,88]},
                index=[1,2,3,4,5])
print(pd.concat([one,two],axis=1))
# Out:
#     Name Subject_id  Mark_scored     Name Subject_id  Mark_scored
# 1   Arun        sci           98     brun        sci           89
# 2   adhi        soc           90    akdhi        soc           80
# 3    ash       stat           87    abash       stat           79
# 4   pata        eng           69  abapata        eng           97
# 5  ayush        mat           78   hayush        mat           88

# %%
import pandas as pd

one=pd.DataFrame({'Name':['Arun','adhi','ash','pata','ayush'],
                 'Subject_id':['sci','soc','stat','eng','mat'],
                 'Mark_scored':[98,90,87,69,78]},
                index=[1,2,3,4,5])

two=pd.DataFrame({'Name':['brun','akdhi','abash','abapata','hayush'],
                 'Subject_id':['sci','soc','stat','eng','mat'],
                 'Mark_scored':[89,80,79,97,88]},
                index=[1,2,3,4,5])
print(pd.concat([one.append(two)]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_45452\3222013252.py in ?()
#       8 two=pd.DataFrame({'Name':['brun','akdhi','abash','abapata','hayush'],
#       9                  'Subject_id':['sci','soc','stat','eng','mat'],
#      10                  'Mark_scored':[89,80,79,97,88]},
#      11                 index=[1,2,3,4,5])
# ---> 12 print(pd.concat([one.append(two)]))
#
# ~\anaconda3\New folder\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
#to get the current time
import pandas as pd

print(pd.datetime.now())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 4
#       1 #to get the current time
#       2 import pandas as pd
# ----> 4 print(pd.datetime.now())
#
# AttributeError: module 'pandas' has no attribute 'datetime'

# %%
#Data Functionality
#Create a range of dates

# %%
import pandas as pd

print (pd.date_range('10/10/2024',periods=5))
# Out:
# DatetimeIndex(['2024-10-10', '2024-10-11', '2024-10-12', '2024-10-13',
#                '2024-10-14'],
#               dtype='datetime64[ns]', freq='D')

# %%
 #change the date frequency
import pandas as pd
print (pd.date_range('10/10/2024',periods=5,freq='M'))
# Out:
# DatetimeIndex(['2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28'],
#               dtype='datetime64[ns]', freq='M')

# %%
import pandas as pd
print (pd.date_range('10/10/2024',periods=5,freq='y'))
# Out:
# DatetimeIndex(['2024-12-31', '2025-12-31', '2026-12-31', '2027-12-31',
#                '2028-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
import pandas as pd
start = pd.datetime(2024,1,1)
end= pd.datetime(2024,1,5)
print (pd.date_range(start,end))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 2
#       1 import pandas as pd
# ----> 2 start = pd.datetime(2024,1,1)
#       3 end= pd.datetime(2024,1,5)
#       4 print (pd.date_range(start,end))
#
# AttributeError: module 'pandas' has no attribute 'datetime'

# %%
#visualisation in pandas
Basic Ploting

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('2/2/2024',periods=10),columns=list('ABCD'))

df.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(10,4),columns=['apple','banana','cherry','pear'])
df.plot.bar()
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(10,4),columns=['apple','banana','cherry','pear'])
df.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(10,4),columns=['apple','banana','cherry','pear'])
df.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randn(10,4),columns=['apple','banana','cherry','pear'])
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#matplotlib is one of the  most popular python package used for data visualization.it is a cross-platform library for making 2d
#Types of plot 
1.Make a Baar Plot
barh

2.Make a Horizontal Bar plot
Boxplot

3.Make a Box and Whisker Plot
Hist

plot a Histrogram
Hist2d

Make a 2d histogram plot
pie

Plot a pie chart
Scatter

Make a scatter plot of x vs y

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.arange(0,math.pi*2,0.05)
y = np.sin(x)
plt.plot(x,y)
plt.xlable("angle")
plt.ylable("sine")
plt.title('sine wave')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[117], line 2
#       1 import numpy as np
# ----> 2 x = np.arange(0,math.pi*2,0.05)
#       3 y = np.sin(x)
#       4 plt.plot(x,y)
#
# NameError: name 'math' is not defined

# %%
from matplotlib import pyplot as plt
import numpy as np
import math #needed for defintion of pi
x = np.arange(0,math.pi*2,0.05)
y = np.sin(x)

plt.plot(x,y)
plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
import math #needed for defintion of pi
x = np.arange(0,math.pi*2,0.05)
y = np.sin(x)

plt.plot(x,y)
plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')
plt.plot(x,y)

# %%
from numpy import *
from pylab import *
x = linspace(-3,3,30)
y = x**2
plot(x,y)
show()

# %%
from pylab import*
x= linspace(-3,3,30)
y= x**2
print(x)
print(y)
plot(x,y,"r.")
show()
# Out:
# [-3.         -2.79310345 -2.5862069  -2.37931034 -2.17241379 -1.96551724
#  -1.75862069 -1.55172414 -1.34482759 -1.13793103 -0.93103448 -0.72413793
#  -0.51724138 -0.31034483 -0.10344828  0.10344828  0.31034483  0.51724138
#   0.72413793  0.93103448  1.13793103  1.34482759  1.55172414  1.75862069
#   1.96551724  2.17241379  2.37931034  2.5862069   2.79310345  3.        ]
# [9.         7.80142687 6.68846611 5.66111772 4.71938169 3.86325803
#  3.09274673 2.4078478  1.80856124 1.29488704 0.86682521 0.52437574
#  0.26753864 0.09631391 0.01070155 0.01070155 0.09631391 0.26753864
#  0.52437574 0.86682521 1.29488704 1.80856124 2.4078478  3.09274673
#  3.86325803 4.71938169 5.66111772 6.68846611 7.80142687 9.        ]

# %%
from pylab import*
plot(x,sin(x))
plot(x,cos(x),"r--")
plot(x,-sin(x),"g")
show()

# %%
#OOI-Object Oriented interface
from matplotlib import pyplot as plt
import numpy as np
import math
x= np.arange(0,math.pi*2,0.07)
y= np.sin(x)
fig= plt.figure()
ax= fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title("sine wave")
ax.set_title("angle")
ax.set_title("sine")
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import math
x= np.arange(0,math.pi*2,0.07)
y= np.sin(x)
fig= plt.figure()
ax= fig.add_axes([1,1,1,1])
ax.plot(x,y)
ax.set_title("sine wave")
ax.set_title("angle")
ax.set_title("sine")
plt.show()

# %%
#subplot function 
import matplotlib.pyplot as plt
fig,a= plt.subplots(2,2)
import numpy as np
x = np.arange(1,5)
a[0][0].plot(x,x*x)
a[0][0].set_title('square')
a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title('squre root')
a[1][0].plot(x,np.exp(x))
a[1][0].set_title('exp')
a[1][1].plot(x,np.log10(x))
a[1][1].set_title('log')
plt.show()

# %%
#subplot2grid()
this function gives more flexibility in creating an axes object at a specific location of the grid.
#plt.subplot2grid(shape,location,rowspan,colspan)

# %%
import matplotlib.pyplot as plt
a1= plt.subplot2grid((3,3),(0,0),colspan=2)
a2= plt.subplot2grid((3,3),(0,2),rowspan=3)
a3= plt.subplot2grid((3,3),(1,0),rowspan=2,colspan=2)
import numpy as np
x = np.arange(1,10)
a2.plot(x,x*x)
a2.set_title("square")
a1.plot(x,np.exp(x))
a1.set_title('exp')
a3.plot(x,np.log(x))
a3.set_title('log')
plt.tight_layout()
plt.show()

# %%
#twin axex()
import matplotlib.pyplot as plt
import numpy as np
fig= plt.figure()
a1= fig.add_axes([0,0,1,1])
x=np.arange(1,11)
a1.plot(x,np.exp(x))
a1.set_ylabel('exp')
a2=a1.twinx()
a2.plot(x,np.log(x),'ro-')
a2.set_ylabel('log')
fig.legend(labels=('exp','log'),loc='upper left')
plt.show()

# %%
#barplot
A Bar chart or Bar graph is a chart or graph that presents catagorial data with rectangular bars with height or length proportinal
matplotlib API provides the bar () function that can be used in the MATLAB style as well as object oriented API.

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax= fig.add_axes([0,0,1,1])
langs=['c','c++','java','python','PHP']
students=[23,17,35,29,12]
ax.bar(langs,students)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = [[30,25,50,20],[40,23,51,17],[35,22,45,19]]
x= np.arange(4)
fig= plt.figure()
ax= fig.add_axes([0,0,1,1])
ax.bar(x+0.25,data[0],color='b',width=0.25)
ax.bar(x+0.75,data[1],color='g',width=0.25)
ax.bar(x+0.50,data[2],color='r',width=0.25)
# Out:
# <BarContainer object of 4 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 5
girlMeans=(20,35,30,35,27)
boysMeans=(25,32,34,20,25)
ind = np.arange(N) #the location for the groups
width = 0.35
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(ind,girlMeans,width,color='r')
ax.bar(ind,boysMeans,width,bottom=boysMeans,color='b')
ax.set_ylabel('scores')
ax.set_title('score by group and gender')
ax.set_xticks(ind,('G1','G2','G3','G4','G5'))
ax.set_yticks(np.arange(0,81,10))
ax.legend(labels=['girl','boys'])
plt.show()

# %%
#Setting ticks and ticks labels
ticks are the marker denoting data points on areas.

# %%
#ax.set_xticks([2,4,6,8,10])
#ax.set_xlabels(['two','four','six','eight','ten'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x= np.arange(0,math.pi*2,0.05)
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
y=np.sin(x)
ax.plot(x,y)
ax.set_xlabel('angle')
ax.set_title('sine')
ax.set_xticks([0,2,4,6])
ax.set_xticklabels(['zero','two','four','six'])
ax.set_yticks([-1,0,1])
plt.show()

# %%
#pie chart
#A pie chart can only display one series of data

from matplotlib import pyplot as plt
import numpy as np
fig= plt .figure()
ax=fig.add_axes([0,0,1,1])
ax.axis('equal')
langs=['c','c++','java','python','PHP']
students=[23,17,35,29,12]
ax.pie(students,labels=langs,autopct='%1.4f%%')
plt.show()

# %%
#CONTOUR PLOT
COUNTOUR PLOTS(Sometimes called level plots) are a way to show a three dimensional surface on a two dimensional plane.

# %%
import numpy as np 
import matplotlib.pyplot as plt
x list =np.linspace(-3.0,3.0,100)
y list = list
# Out:
#   Cell In[4], line 3
#     x list =np.linspace(-3.0,3.0,100)
#       ^
# SyntaxError: invalid syntax

# %%
import numpy as np 
import matplotlib.pyplot as plt
xlist =np.linspace(-3.0,3.0,100)
ylist =np.linspace(-3.0,3.0,100)
x,y =np.meshgrid(xlist,ylist) #create an rectangular grid outside of an array
z= np.sqrt(x**2+y**2)
fig,ax=plt.subplots(1,1)
cp=ax.contourf(x,y,z)
fig.colorbar(cp) #add a colourbar to a plot
ax.set_title('filled contour plot')
ax.set_xlable('x(cm)')
ax.set_ylable('y(cm)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 11
#       9 fig.colorbar(cp) #add a colourbar to a plot
#      10 ax.set_title('filled contour plot')
# ---> 11 ax.set_xlable('x(cm)')
#      12 ax.set_ylable('y(cm)')
#      13 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'set_xlable'
